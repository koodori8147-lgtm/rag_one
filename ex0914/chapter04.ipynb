# %%
#!pip --version
# Out:
# pip 26.2.1 from C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip (python 3.12)

# %%
#!pip install langchain_openai

# %%
#%pip install -qU langchain-teddynote
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import langchain_teddynote
print("teddynote import 성공")
# Out:
# teddynote import 성공

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    temperature=1.0,
    model_name="gpt-4o-mini",
)

question = "성심당의 인기 메뉴는 무엇인가요?"

print(f"[답변]: {llm.invoke(question)}")
# Out:
# [답변]: content='성심당은 대전에서 유명한 제과점으로, 다양한 빵과 디저트를 제공합니다. 특히 인기 있는 메뉴에는 다음과 같은 것들이 있습니다:\n\n1. **앙버터**: 팥과 버터가 들어간 빵으로, 고소한 맛과 달콤함이 조화를 이룹니다.\n2. **세종빵**: 부드러운 식감과 고소한 맛으로 많은 사랑을 받고 있는 메뉴입니다.\n3. **크림빵**: 크림이 가득 들어 있어 부드럽고 달콤한 맛이 매력적입니다.\n4. **소보로빵**: 겉면의 바삭한 소보로와 속의 부드러운 식감이 잘 어우러지는 인기 간식입니다.\n\n성심당의 빵은 신선한 재료로 만들어져 많은 사람들이 찾는 이유 중 하나입니다. 대전 지역을 방문한다면 꼭 한번 시도해 보세요!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 208, 'prompt_tokens': 18, 'total_tokens': 226, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8156e398b1', 'id': 'chatcmpl-ENv8lFosy3UjsJrZFyLCoqtZjjiY1', 'service_tier': 'default', 'finish_reas
# ...

# %%
llm = ChatOpenAI(
    temperature=1.0,
    model_name="gpt-4o-mini",
)

question = "성심당의 인기 메뉴는 무엇인가요?"

response = llm.invoke(question)

print(f"[답변]: {response}")
# Out:
# [답변]: content='성심당은 유명한 제과점으로, 특히 다음과 같은 인기 메뉴가 있습니다:\n\n1. **앙금빵**: 부드러운 빵 속에 달콤한 팥 앙금이 들어간 전통적인 빵입니다.\n2. **튀김소보루**: 바삭한 식감과 고소한 맛이 특징인 소보루.\n3. **버터롤**: 부드럽고 촉촉한 식감의 빵으로 버터의 풍미가 가득합니다.\n4. **초코롤**: 초콜릿으로 맛을 낸 롤케이크로, 달콤한 맛이 인기입니다.\n5. **파이류**: 다양한 맛의 파이도 인기 메뉴 중 하나입니다.\n\n이 외에도 성심당은 다양한 빵과 디저트를 제공하여 많은 사람들에게 사랑받고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 189, 'prompt_tokens': 18, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8156e398b1', 'id': 'chatcmpl-ENv9oNvvf0Kj00v5kMBQ6mF6CnF32', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--
# ...

# %%
response.content
# Out:
# '성심당은 유명한 제과점으로, 특히 다음과 같은 인기 메뉴가 있습니다:\n\n1. **앙금빵**: 부드러운 빵 속에 달콤한 팥 앙금이 들어간 전통적인 빵입니다.\n2. **튀김소보루**: 바삭한 식감과 고소한 맛이 특징인 소보루.\n3. **버터롤**: 부드럽고 촉촉한 식감의 빵으로 버터의 풍미가 가득합니다.\n4. **초코롤**: 초콜릿으로 맛을 낸 롤케이크로, 달콤한 맛이 인기입니다.\n5. **파이류**: 다양한 맛의 파이도 인기 메뉴 중 하나입니다.\n\n이 외에도 성심당은 다양한 빵과 디저트를 제공하여 많은 사람들에게 사랑받고 있습니다.'

# %%
response.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 189,
#   'prompt_tokens': 18,
#   'total_tokens': 207,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 0,
#    'rejected_prediction_tokens': 0,
#    'text_tokens': None},
#   'prompt_tokens_details': {'audio_tokens': 0,
#    'cache_write_tokens': None,
#    'cached_tokens': 0,
#    'image_tokens': None,
#    'text_tokens': None}},
#  'model_provider': 'openai',
#  'model_name': 'gpt-4o-mini-2024-07-18',
#  'system_fingerprint': 'fp_8156e398b1',
#  'id': 'chatcmpl-ENv9oNvvf0Kj00v5kMBQ6mF6CnF32',
#  'service_tier': 'default',
#  'finish_reason': 'stop',
#  'logprobs': None}

# %%
llm_with_logprob = ChatOpenAI(
    temperature=1.0,
    max_tokens=2048,
    model_name="gpt-4o-mini",
).bind(logprobs=True)

question = "도쿄의 맛집은 어디인가요?"

response = llm_with_logprob.invoke(question)

response.response_metadata

response.response_metadata["logprobs"]
# Out:
# {'content': [{'token': '도',
#    'bytes': [235, 143, 132],
#    'logprob': -5.204720582696609e-05,
#    'top_logprobs': []},
#   {'token': '\\xec\\xbf',
#    'bytes': [236, 191],
#    'logprob': -1.1472419600977446e-06,
#    'top_logprobs': []},
#   {'token': '\\x84',
#    'bytes': [132],
#    'logprob': -4.320199877838604e-07,
#    'top_logprobs': []},
#   {'token': '에는',
#    'bytes': [236, 151, 144, 235, 138, 148],
#    'logprob': -0.06205451115965843,
#    'top_logprobs': []},
#   {'token': ' 다양한',
#    'bytes': [32, 235, 139, 164, 236, 150, 145, 237, 149, 156],
#    'logprob': -0.5918694734573364,
#    'top_logprobs': []},
#   {'token': ' 맛',
#    'bytes': [32, 235, 167, 155],
#    'logprob': -0.002754949266090989,
#    'top_logprobs': []},
#   {'token': '집',
#    'bytes': [236, 167, 145],
#    'logprob': -4.7994282795116305e-05,
#    'top_logprobs': []},
#   {'token': '이',
#    'bytes': [236, 157, 180],
#    'logprob': -0.03464788943529129,
#    'top_logprobs': []},
# ...

# %%
question = "도쿄의 맛집은 어디인가요?"
answer = llm.stream(question)

for token in answer : 
    print(token.content,end="",flush=True)
# Out:
# 도쿄에는 정말 다양한 맛집이 있습니다. 몇 가지 추천드릴 만한 장소를 소개해드릴게요.
#
# 1. **스시 다이 (Sushi Dai)** - 츠키지 시장 근처에 위치한 유명한 스시집으로, 신선한 재료로 만든 스시를 맛볼 수 있습니다.
#
# 2. **도게츠 (Togetsu)** - 전통적인 이자카야 스타일의 식당으로, 일본식 술과 함께 다양한 안주를 즐길 수 있습니다.
#
# 3. **멘야 무사시 (Menya Musashi)** - 진하고 깊은 맛의 라멘으로 유명한 곳입니다. 특히 구운 돈코츠 육수가 특징입니다.
#
# 4. **규카츠 고로 (Gyukatsu Goro)** - 소고기 규카츠(돈까스처럼 튀긴 고기)를 전문으로 하는 레스토랑으로, 고기를 직접 구워 먹는 재미가 있습니다.
#
# 5. **시부야의 이치란 라멘 (Ichiran Ramen)** - 프라이빗한 공간에서 라멘을 즐길 수 있는 체인점으로, 깊고 풍부한 국물 맛이 일품입니다.
#
# 6. **우동 우마이 (Udon Umai)** - 신선한 면발과 진한 육수로 유명한 우동 전문점입니다.
#
# 도쿄는 맛있는 음식이 가득한 도시이니, 다양한 음식을 시도해 보시길 추천합니다!

# %%
question = "도쿄의 맛집은 어디인가요?"
answer = llm.stream(question)

final_answer = ""
for token in answer:
    final_answer += token.content

final_answer
# Out:
# '도쿄에는 많은 맛집이 있습니다. 여기 몇 가지 추천해드릴게요:\n\n1. **스시 잔마이 (Sushi Zanmai)** - 신선한 스시를 합리적인 가격에 즐길 수 있는 곳입니다. 여러 지점이 있으며, 24시간 운영하는 곳도 많습니다.\n\n2. **라멘 잔마이 (Ramen Nagi)** - 다양한 종류의 라멘을 제공하는 인기 있는 라멘집입니다. 특히, 맞춤형 주문이 가능해 자신만의 라멘을 만들 수 있습니다.\n\n3. **이자카야 카사사 (Izakaya Kasasa)** - 전통적인 일본식 선술집으로, 다양한 일본 음식과 술을 즐길 수 있는 곳입니다. 아늑한 분위기가 매력적입니다.\n\n4. **오모이데 요코초 (Omoide Yokocho)** - 여러 개의 작은 이자카야가 모여 있는 거리로, 현지인들이 자주 찾는 곳입니다. 다양한 일본 전통 음식을 경험할 수 있습니다.\n\n5. **가츠 돈 전문점 잔바이 (Katsudon Zambai)** - 맛있는 가츠돈(돈까스 덮밥)을 전문으로 하는 곳입니다. 바삭한 돈까스와 부드러운 밥이 일품입니다.\n\n이 외에도 도쿄에는 많은 명물 음식점들이 있으니, 취향에 맞게 탐험해보세요!'
