# %%
# !pip --version

# %%
# %pip --version
# Out:
# pip 25.0.1 from d:\hanwha_0902\hanwha_0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

import logging
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_teddynote.messages import stream_response

logging.basicConfig(
    filename="app.log",             # 저장될 로그 파일 이름
    level=logging.INFO,             # 로깅 레벨 (INFO, DEBUG, ERROR 등)
    format="%(asctime)s - %(levelname)s - %(message)s", # 로그 포맷 (시간 - 레벨 - 메시지)
    encoding="utf-8"                # 한글 깨짐 방지
)

logger = logging.getLogger("MyMultimodalApp")

logger.info("LangSmith 연동 및 애플리케이션 시작2")

try:
    multimodal_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

    IMAGE_URL = "https://t3.ftcdn.net/jpg/03/77/33/96/360_F_377339633_Rtv9I77sSmSNcev8bEcnVxTHrXB4nRJ5.jpg"
    prompt = "이미지의 내용을 한국어로 상세히 설명해 주세요."

    logger.info(f"요청 전송 - Prompt: {prompt} / Image: {IMAGE_URL}")

    message = HumanMessage(
        content=[
            {"type": "text", "text": prompt},
            {"type": "image_url", "image_url": {"url": IMAGE_URL}},
        ]
    )

    answer = multimodal_llm.stream([message])
    
    logger.info("답변 수신 및 스트리밍 시작")
    stream_response(answer)
    logger.info("답변 처리 완료")

except Exception as e:

    logger.error(f"실행 중 에러 발생: {str(e)}", exc_info=True)
# Out:
# 이 이미지는 표 형식으로 구성된 데이터입니다. 표의 제목은 "TABLE 001: LOREM IPSUM DOLOR AMIS ENIMA ACCUMMER TUNA"입니다. 표는 여러 열과 행으로 나뉘어 있으며, 각 열은 다음과 같은 제목을 가지고 있습니다:
#
# 1. **Loremis**: 첫 번째 열에는 숫자 데이터가 포함되어 있습니다.
# 2. **Amis terim**: 두 번째 열에는 백분율이 포함되어 있습니다.
# 3. **Gato lepis**: 세 번째 열에는 "YES" 또는 "NO"와 같은 값이 포함되어 있습니다.
# 4. **Tortores**: 네 번째 열에는 가격이 포함되어 있습니다.
#
# 각 행은 특정 항목에 대한 정보를 나타내며, 예를 들어 첫 번째 행은 "Lorem dolor siamet"이라는 항목에 대한 데이터입니다. 이 항목은 8,288이라는 숫자와 123%라는 백분율, "YES"라는 값, 그리고 $89라는 가격을 가지고 있습니다.
#
# 표의 하단에는 "Lorem ipsum dolor sit amet..."로 시작하는 설명이 있으며, 이는 일반적으로 텍스트의 예시로 사용되는 라틴어 문구입니다. 이 설명은 표의 내용과 관련된 추가 정보를 제공하는 것으로 보입니다.

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_teddynote import logging
logging.langsmith("test_0914")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# test_0914

# %%
from langchain_core.prompts import PromptTemplate

template = "성심당의 수도는 어디인가요?"

prompt_template = PromptTemplate.from_template(template)
prompt_template
# Out:
# PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='성심당의 수도는 어디인가요?')
