# %%
#가상환경 위치 확인
#!pip --version

# %%
# 패키지 : dotenv 설치
#!pip install dotenv

# %%
from dotenv import load_dotenv

#.env 파일에 설정된 보안정보를 읽기
load_dotenv()
# Out:
# True

# %%
import os

# 설정된 API 키값 불러오기
print(f"키값은:{os.environ['OPEN_API_KEY'][:13]}")
# Out:
# 키값은:sk-proj-jkqb6
