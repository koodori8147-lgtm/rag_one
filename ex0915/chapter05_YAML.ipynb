# %%
# %pip --version
# Out:
# pip 25.0.1 from d:\hanwha_0902\hanwha_0902\ex0915\.venv\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
_type: "prompt"
template: "{fruit}의 색깔이 뭐야?"
input_variables: ["fruit"]

from langchain_core.prompts import load_prompt
prompt= load_prompt("fruit_color.yaml", encoding="utf-8")
prompt
# Out:
# PromptTemplate(input_variables=['fruit'], input_types={}, partial_variables={}, template='{fruit}의 색깔이 뭐야?')

# %%
import os
print(os.path.exists("fruit_color.yaml"))
# Out:
# True

# %%
prompt.format(fruit="사과")
# Out:
# '사과의 색깔이 뭐야?'

# %%
prompt2 = load_prompt("capital.yaml", encoding="utf-8")
print(prompt2.format(country="대한민국"))
# Out:
# 대한민국의 수도에 대해서 알려주세요.
# 수도의 특징을 다음의 양식에 맞게 정리해 주세요.
# 300자 내외로 작성해 주세요.
# 한글로 작성해 주세요.
# ----
# [양식]
# 1. 면적
# 2. 인구
# 3. 역사적 장소
# 4. 특산품
#
# #Answer:

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_teddynote.messages import stream_response
from langchain_openai import ChatOpenAI

chain = prompt2 | ChatOpenAI(model_name="gpt-4o", temperature = 0.5) | StrOutputParser()

answer = chain.stream({"country": "헝가리"})
stream_response(answer)
# Out:
# 1. 면적: 헝가리의 수도 부다페스트는 약 525.2 제곱킬로미터의 면적을 가지고 있습니다. 이 도시는 도나우 강을 중심으로 부다와 페스트 두 지역으로 나뉘어 있습니다.
#
# 2. 인구: 부다페스트의 인구는 약 175만 명으로, 헝가리에서 가장 인구가 많은 도시입니다. 다양한 문화와 역사를 가진 도시로서 다채로운 인구 구성을 자랑합니다.
#
# 3. 역사적 장소: 부다페스트는 많은 역사적 장소로 유명합니다. 대표적인 곳으로는 부다 성, 국회의사당, 세체니 다리, 어부의 요새 등이 있습니다. 이들 장소는 유네스코 세계문화유산으로 지정되어 있으며, 도시의 풍부한 역사와 문화를 보여줍니다.
#
# 4. 특산품: 부다페스트는 헝가리의 전통 음식과 와인으로 유명합니다. 특히 파프리카, 구야시(굴라쉬)와 같은 전통 음식과 함께 토카이 와인이 특산품으로 꼽힙니다. 이 외에도 헝가리의 전통 도자기와 수공예품도 인기 있는 기념품입니다.
